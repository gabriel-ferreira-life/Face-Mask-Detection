# %%
from google.colab import drive
import pandas as pd


data_loc = "/content/drive/My Drive/data_storage/textdata.csv"

test_df = pd.read_csv(data_loc)
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4573f9596985> in <cell line: 7>()
#       5 data_loc = "/content/drive/My Drive/data_storage/textdata.csv"
#       6
# ----> 7 test_df = pd.read_csv(data_loc)
#       8 test_df.head()
#
# ...

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive to Colab
drive.mount('/content/drive')

# Define the path to your data file
data_loc = "/content/drive/My Drive/data_storage/textdata.csv"

# Read the CSV file into a pandas DataFrame
test_df = pd.read_csv(data_loc)

# Display the first few rows of the DataFrame
test_df.head()
# Out:
# Mounted at /content/drive
#       textid                                               text  \
# 0  c12129c31  When the young people returned to the ballroom...
# 1  85aa80a4c  All through dinner time, Mrs. Fayre was somewh...
# 2  b69ac6792  As Roger had predicted, the snow departed as q...
# 3  dd1000b26  And outside before the palace a great garden w...
# 4  37c1b32fb  Once upon a time there were Three Bears who li...
#
#    Bradly_Terry_Score
# 0           -0.340259
# 1           -0.315372
# 2           -0.580118
# 3           -1.054013
# 4            0.247197

# %%
for i in range(10):
  print(f'oi gabriel i love you manda pix de ${i*50}')
# Out:
# oi gabriel i love you manda pix de $0
# oi gabriel i love you manda pix de $50
# oi gabriel i love you manda pix de $100
# oi gabriel i love you manda pix de $150
# oi gabriel i love you manda pix de $200
# oi gabriel i love you manda pix de $250
# oi gabriel i love you manda pix de $300
# oi gabriel i love you manda pix de $350
# oi gabriel i love you manda pix de $400
# oi gabriel i love you manda pix de $450
